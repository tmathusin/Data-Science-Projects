# %%
# Reloading
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
print('pandas version:{}'.format(pd.__version__))
import numpy as np
print('numpy version:{}'.format(np.__version__))
import math
from datetime import datetime
from dgpylib import dg_athena
from dgpylib import dg_s3
import os
import re
from matplotlib.ticker import MaxNLocator
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import timedelta
from dateutil.relativedelta import relativedelta

import sys
sys.path.insert(0, '../Modelling')
import helper_function2 as hf

import sys
sys.path.insert(0, '../EDA')
import data_integrity_fixer as dint
import basicstatsandplotter as bsp
import data_imputer as di
import data_integrity_fixer as dif
import parameters

##for modelling
import h2o
print('h2o version:{}'.format(h2o.__version__))
from h2o.estimators import H2OXGBoostEstimator
from h2o.grid.grid_search import H2OGridSearch
from h2o.estimators.glm import H2OGeneralizedLinearEstimator
from h2o.estimators import H2OTargetEncoderEstimator
from h2o.estimators import H2ORandomForestEstimator
from h2o.estimators import H2OGradientBoostingEstimator
from h2o.tree import H2OTree
from h2o.tree import H2ONode
from h2o.tree import H2OSplitNode
from h2o.tree import H2OLeafNode
from h2o.estimators.kmeans import H2OKMeansEstimator

#import xgboost as xgb
import sklearn
import category_encoders as ce
print('sklearn version:{}'.format(sklearn.__version__))
from sklearn import datasets
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import r2_score
from sklearn.preprocessing import PowerTransformer
import time
import parameters
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %run 'functions.ipynb'

plt.rcParams['figure.figsize'] = [10, 5]
plt.rcParams['figure.dpi'] = 100
# Out:
# pandas version:1.3.4
# numpy version:1.20.3
# h2o version:3.36.0.4
# sklearn version:1.1.2

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
cnx = dg_athena.Connect()

query = """ select * from sam_mccouig_db.prq_ptoc_em_1m_training """

df_raw = cnx.read(query)

# %%
conn_s3 = dg_s3.Connect('dgdatadump/DS&CA/Pricing/02 Projects/2022/Tel_Reg_2.0/Cancellation Model')
conn_s3.write(df_raw, 'churn_prq_ptoc_em_1m_training.csv')
# Out:
# File saved as :churn_prq_ptoc_em_1m_training.csv

# %%
data_list = ['df_raw3', 'df_raw6', 'df_raw9', 'df_raw12']
data_set = [df_raw3, df_raw6, df_raw9, df_raw12]

# %%
for i in data_set:
    print(i.cancelflag.astype(int).mean())
# Out:
# 0.1245960040105529
# 0.16861956545845685
# 0.20206293685458737
# 0.2332909783989835

# %%
for i in data_set:
    i.drop('RouteToMarketName', axis=1, inplace=True)

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# Warning: Your H2O cluster version is too old (2 years, 3 months and 7 days)! Please download and install the latest version from http://h2o.ai/download/
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         1 hour 45 mins
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.30.0.4
# H2O_cluster_version_age:    2 years, 3 months and 7 days !!!
# H2O_cluster_name:           H2O_from_python_ubuntu_vwxp7y
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    27.71 Gb
# H2O_cluster_total_cores:    16
# H2O_cluster_allowed_cores:  16
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.8.13 final
# --------------------------  ------------------------------------------------------------------

# %%
df_filt = df_raw12.copy()

# %%
categorical_cols, integer_cols, float_cols, date_cols, unidentified_cols = hf.cat_num_split(df_filt)

# %%
predictors = list(set(categorical_cols + float_cols + integer_cols) - set(['cancelflag']))
response = 'cancelflag'

# %% [markdown]
# ## Feature Importance
# <a id='featimp'></a>

# %%
performance_df = pd.DataFrame(columns =['name','varimp', 'feats_stored_gbm', 'perf_metrics', 'classif_rep', 'xval_auc', 'xval_metrics'])
for idx, dataset in enumerate(data_list):
    if (dataset == 'df_raw12'):
        df = df_raw12
    elif (dataset == 'df_raw9'): 
        df = df_raw9
    elif (dataset == 'df_raw6'): 
        df = df_raw6
    else:
        df = df_raw3
    # # convert columns to factors
    # for i in df.columns:
    #     df[i] = df[i].astype('category')
        
    #train test split
    x_train, x_test, y_train, y_test = train_test_split(df[predictors], df[response], test_size = 0.2, random_state = 1)
    train = pd.concat([x_train, y_train], axis=1)
    test = pd.concat([x_test, y_test], axis=1)

    # preserve training & test data's index to be used as a key to merge prediction probability with main dataset 
    xtrain_index = x_train.index
    xtest_index = x_test.index

    # convert to h2o dataframe format
    hf_train = h2o.H2OFrame(train)
    hf_test = h2o.H2OFrame(test)

    # format target to fit the model
    hf_train['cancelflag']=hf_train['cancelflag'].asfactor()
    hf_test['cancelflag']=hf_test['cancelflag'].asfactor()

    # initialise the estimator 
    df_gbm_imp = H2OGradientBoostingEstimator(keep_cross_validation_predictions=True, nfolds = 5, seed = 1)
    start = time.time()

    # train the model
    df_gbm_imp.train(x = predictors, y = response, training_frame = hf_train)
    end = time.time()
    print(end - start)
    
    # Retrieve the variable importance
    varimp = df_gbm_imp.varimp(use_pandas=True).sort_values('scaled_importance', ascending=False)
    feats_stored_gbm = list(varimp.head(20)['variable'])
    
    #perf metrics
    perf_metrics = model_perf_stats(df_gbm_imp, hf_train, hf_test)
    
    y_true = y_test
    y_pred = df_gbm_imp.predict(hf_test)
    y_pred = y_pred.as_data_frame()
    
    # classification report
    classif_rep = classification_report(y_true, y_pred['predict'], labels=[0,1])
    
    # AUC of cross-validated holdout predictions
    xval_auc = f'AUC of cross-validated holdout predictions: {df_gbm_imp.auc(xval=True)}'
    
    xval_metrics = df_gbm_imp.cross_validation_metrics_summary()
    
    performance_df.loc[idx,:] = [dataset, varimp, feats_stored_gbm, perf_metrics, classif_rep, xval_auc, xval_metrics]
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm Model Build progress: |███████████████████████████████████████████████| 100%
# 54.01839327812195
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm Model Build progress: |███████████████████████████████████████████████| 100%
# 41.54326152801514
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm Model Build progress: |███████████████████████████████████████████████| 100%
# 29.32128596305847
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm Model Build progress: |███████████████████████████████████████████████| 100%
# 18.133413076400757
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)

# %%
# print performance metrics for all datasets
for i in range(len(performance_df)):
    for j in ['name','perf_metrics','feats_stored_gbm','classif_rep', 'xval_auc']:

        print(performance_df.loc[i,j])
# Out:
# df_raw3
# ['MCC: 0.16007 / 0.13143', 'F1: 0.27060 / 0.26006', 'AUC: 0.64031 / 0.62245', 'AUC PR: 0.24649 / 0.21874', 'Accuracy: 0.87903 / 0.87777', 'Logloss: 0.35843 / 0.36233']
# ['ONS_%people_working_FT', 'ManufacturerBrandCode', 'ONS_avg_age', 'PlansAcceptedPast1YearCount', 'PlanLiveCount', 'ClientAccountDesc', 'PlansActivePast5yrCount', 'AppAge', 'ClientGroupDesc', 'PurchasePrice', 'ApplianceCode', 'Fee', 'ONS_n_families_per_population', 'ONS_avg_dependent_children_per_family', 'ONS_bedrooms per rooms', 'ONS_avg_distance_travelled_to_work(km)', 'price_diff', 'ONS_%people_working_49+', 'GoodsColour', 'ONS_avg_household_size']
#               precision    recall  f1-score   support
#
#            0       0.90      0.67      0.77     62513
#            1       0.18      0.49      0.26      8899
#
#     accuracy                           0.65     71412
#    macro avg       0.54      0.58      0.51     71412
# weighted avg       0.81      0.65      0.71     71412
#
# AUC of cross-validated holdout predictions: 0.6167349119907137
# df_raw6
# ['MCC: 0.17107 / 0.14294', 'F1: 0.33489 / 0.32056', 'AUC: 0.64317 / 0.62335', 'AUC PR: 0.31089 / 0.27792', 'Accuracy: 0.83652 / 0.83725', 'Logloss: 0.43212 / 0.43311']
# ['PlansAcceptedPast1YearCount', 'PlanLiveCount', 'ManufacturerBrandCode', 'AppAge', 'ONS_avg_age', 'ClientAccountDesc', 'ONS_%people_working_FT', 'PurchasePrice', 'PlansAcceptedPast5YearCount', 'ApplianceCode', 'ClientGroupDesc', 'GoodsColour', 'PlansActivePast5yrCount', 'ONS_avg_rooms', 'offertotalprice', 'ONS_avg_dependent_children_per_family', 'ONS_%people_working_49+', 'ONS_n_families_per_population', 'price_diff', 'Fee']
#               precision    recall  f1-score   support
#
#            0       0.88      0.58      0.70     45096
#            1       0.22      0.59      0.32      9012
#
#     accuracy                           0.58     54108
#    macro avg       0.55      0.58      0.51     54108
# weighted avg       0.77      0.58      0.64     54108
#
# AUC of cross-validated holdout predictions: 0.6213818337156749
# df_raw9
# ['MCC: 0.18542 / 0.15537', 'F1: 0.37972 / 0.36394', 'AUC: 0.64900 / 0.62206', 'AUC PR: 0.36261 / 0.32620', 'Accuracy: 0.80618 / 0.80402', 'Logloss: 0.47727 / 0.48199']
# ['PlansAcceptedPast1YearCount', 'PlanLiveCount', 'AppAge', 'ManufacturerBrandCode', 'ONS_%people_working_FT', 'ClientAccountDesc', 'ONS_avg_age', 'PlansAcceptedPast5YearCount', 'GoodsColour', 'PurchasePrice', 'ApplianceCode', 'ClientGroupDesc', 'ONS_avg_dependent_children_per_family', 'relFee', 'ONS_n_families_per_population', 'ONS_occupation_rate', 'HPI_SalesVolume', 'ONS_avg_rooms', 'ONS_%people_working_49+', 'ONS_avg_bedrooms']
#               precision    recall  f1-score   support
#
#            0       0.85      0.54      0.66     26819
#            1       0.25      0.62      0.36      6745
#
#     accuracy                           0.56     33564
#    macro avg       0.55      0.58      0.51     33564
# weighted avg       0.73      0.56      0.60     33564
#
# AUC of cross-validated holdout predictions: 0.6193282939394466
# df_raw12
# ['MCC: 0.25939 / 0.17274', 'F1: 0.45015 / 0.41017', 'AUC: 0.69575 / 0.63473', 'AUC PR: 0.46292 / 0.37695', 'Accuracy: 0.78679 / 0.77435', 'Logloss: 0.50202 / 0.51991']
# ['ClientAccountDesc', 'AppAge', 'PlansAcceptedPast1YearCount', 'PlanLiveCount', 'ManufacturerBrandCode', 'ONS_%people_working_FT', 'ONS_avg_bedrooms', 'PlansAcceptedPast5YearCount', 'ONS_population_density', 'ApplianceCode', 'ClientGroupDesc', 'ONS_avg_rooms', 'ONS_avg_age', 'HPI_AveragePrice', 'ONS_avg_dependent_children_per_family', 'HPI_SalesVolume', 'ONS_n_families_per_population', 'ONS_%people_working_49+', 'ONS_n_families', 'relFee']
#               precision    recall  f1-score   support
#
#            0       0.83      0.60      0.70     10246
#            1       0.31      0.58      0.41      3133
#
#     accuracy                           0.60     13379
#    macro avg       0.57      0.59      0.55     13379
# weighted avg       0.71      0.60      0.63     13379
#
# AUC of cross-validated holdout predictions: 0.634289290069386

# %%
# print cross-validated performance metrics for all cancellation cohorts
for i in range(len(performance_df)):
    print(performance_df.loc[i,'name'])
    print(performance_df.loc[i,'xval_metrics'])
# Out:
# df_raw3
#
# Cross-Validation Metrics Summary:
#                                     mean            sd   cv_1_valid  \
# 0                  accuracy   0.59583294    0.03645432   0.61825204
# 1                       auc    0.6167946  0.0018823637   0.61714303
# 2                     aucpr    0.2175631  0.0027666995   0.21536866
# 3                       err    0.4041671    0.03645432   0.38174796
# 4                 err_count      23092.4     2120.4333      21844.0
# 5                  f0point5   0.19395326  0.0055604596   0.19817168
# 6                        f1    0.2565247  0.0033061386   0.25932455
# 7                        f2    0.3793407   0.011950488   0.37506375
# 8            lift_top_group     4.394178    0.13342872    4.2387724
# 9                   logloss   0.36246184  0.0026601504    0.3638835
# 10      max_per_class_error   0.46464872    0.01922339   0.46607092
# 11                      mcc  0.107924834  0.0029561918   0.11141665
# 12  mean_per_class_accuracy    0.5802807  0.0014415323    0.5821226
# 13     mean_per_class_error    0.4197193  0.0014415323   0.41787735
# 14                      mse   0.10515958  0.0010654455   0.10571255
# 15                   pr_auc    0.2175631  0.0027666995   0.21536866
# 16                precision   0.16685526   0.006074227   0.17124943
# 17                       r2  0.035826467  0.0011329708  0.034569666
# 18                   recall    0.5594902   0.048418492   0.53392905
# 19                     rmse   0.32427984  0.0016462316   0.32513466
#
#      cv_2_valid   cv_3_valid   cv_4_valid   cv_5_valid
# 0     0.5668328   0.54846543    0.6111209    0.6344935
# 1     0.6193218   0.61411124    0.6171705   0.61622626
# 2    0.22030607   0.21475072   0.22067074   0.21671927
# 3    0.43316725   0.45153457   0.38887915   0.36550647
# 4       24775.0      25849.0      22170.0      20824.0
# 5    0.19283624   0.18541278   0.19376592   0.19957972
# 6    0.25865525   0.25159964    0.2546396   0.25840455
# 7    0.39268777   0.39127225    0.3712818   0.36639804
# 8      4.483228     4.556182     4.410821     4.281885
# 9     0.3645213    0.3581977   0.36152044   0.36418632
# 10   0.43793884   0.46165326   0.46549046   0.49209017
# 11  0.107881576  0.104551524   0.10550189  0.110272534
# 12   0.58100283    0.5797523   0.57825124    0.5802744
# 13   0.41899717   0.42024764   0.42174873    0.4197256
# 14  0.106019825   0.10344714   0.10480045   0.10581796
# 15   0.22030607   0.21475072   0.22067074   0.21671927
# 16   0.16486745    0.1577476   0.16713005   0.17328174
# 17   0.03697473  0.035543002  0.037042085   0.03500285
# 18    0.5999445   0.62115794   0.53450954   0.50790983
# 19   0.32560685     0.321632   0.32372898   0.32529673
# See the whole table with table.as_data_frame()
#
# df_raw6
#
# Cross-Validation Metrics Summary:
#                                    mean            sd   cv_1_valid  \
# 0                  accuracy  0.54556435   0.026362866   0.51812196
# 1                       auc  0.62143755  0.0038759457     0.617482
# 2                     aucpr  0.28136352  0.0047666025    0.2762652
# 3                       err  0.45443562   0.026362866   0.48187804
# 4                 err_count     19674.0     1212.9845      20927.0
# 5                  f0point5  0.24878915  0.0031881437   0.24509513
# 6                        f1   0.3225845  0.0037912936   0.32189494
# 7                        f2  0.45892206   0.013867518   0.46878836
# 8            lift_top_group   4.0142903    0.09080743    3.9272923
# 9                   logloss  0.43721113  0.0024863705   0.43882143
# 10      max_per_class_error  0.47370985    0.03959357    0.5137009
# 11                      mcc  0.12483823  0.0037378697   0.12058493
# 12  mean_per_class_accuracy    0.583045   0.002399327   0.58003235
# 13     mean_per_class_error  0.41695502   0.002399327   0.41996765
# 14                      mse  0.13475004  0.0010659735   0.13538525
# 15                   pr_auc  0.28136352  0.0047666025    0.2762652
# 16                precision  0.21588494  0.0035874073   0.21146068
# 17                       r2  0.04108939  0.0010961863  0.039387714
# 18                   recall  0.63979983   0.038382992    0.6737656
# 19                     rmse  0.36708087  0.0014528554   0.36794734
#
#     cv_2_valid   cv_3_valid   cv_4_valid   cv_5_valid
# 0   0.55291533   0.51839757   0.56150675    0.5768803
# 1   0.62577355   0.62360996     0.617189    0.6231332
# 2    0.2878656   0.28425398   0.28080338   0.27762944
# 3    0.4470847   0.48160243   0.43849325   0.42311972
# 4      19323.0      20942.0      18928.0      18250.0
# 5    0.2533339   0.24792984   0.24711743   0.25046945
# 6   0.32707644       0.3258    0.3181065    0.3200447
# 7   0.46137825   0.47498357   0.44632027   0.44313985
# 8    3.9699244    3.9574683    4.1438193     4.072946
# 9   0.43951446   0.43865243   0.43498933   0.43407807
# 10  0.46407837    0.5155059   0.44831905   0.42694503
# 11  0.12893987   0.12690647  0.121154286   0.12660562
# 12   0.5856015   0.58409274    0.5809967    0.5845017
# 13   0.4143985   0.41590726    0.4190033   0.41549832
# 14  0.13578366   0.13538404   0.13369843   0.13349883
# 15   0.2878656   0.28425398   0.28080338   0.27762944
# 16  0.22023168   0.21385401   0.21511401   0.21876432
# 17  0.04229334  0.041408848   0.04159287  0.040764187
# 18   0.6352814    0.6836914    0.6103124    0.5959484
# 19  0.36848834    0.3679457   0.36564797   0.36537492
# See the whole table with table.as_data_frame()
#
# df_raw9
#
# Cross-Validation Metrics Summary:
#                                     mean            sd   cv_1_valid  \
# 0                  accuracy   0.51351833   0.007421214    0.5166009
# 1                       auc   0.61954945  0.0044063814    0.6180751
# 2                     aucpr    0.3224064  0.0067246174   0.32744983
# 3                       err   0.48648164   0.007421214    0.4833991
# 4                 err_count      13061.8     140.33069      12987.0
# 5                  f0point5   0.28401414   0.006326591    0.2837141
# 6                        f1   0.36428753  0.0074720015   0.36272633
# 7                        f2    0.5078612   0.010160475     0.502734
# 8            lift_top_group    3.7247496   0.102922365     3.640082
# 9                   logloss    0.4846656  0.0034845513   0.48565364
# 10      max_per_class_error   0.53100383   0.012309218   0.52429223
# 11                      mcc   0.12800801   0.008130199   0.12359674
# 12  mean_per_class_accuracy    0.5789833  0.0045735175    0.5763154
# 13     mean_per_class_error   0.42101672  0.0045735175    0.4236846
# 14                      mse   0.15443255  0.0015326747     0.154802
# 15                   pr_auc    0.3224064  0.0067246174   0.32744983
# 16                precision   0.24763821  0.0057830065   0.24773778
# 17                       r2  0.043087598  0.0013415308  0.044007674
# 18                   recall   0.68897045   0.016711397    0.6769231
# 19                     rmse   0.39297518  0.0019508612   0.39344886
#
#     cv_2_valid  cv_3_valid   cv_4_valid   cv_5_valid
# 0   0.51459485  0.52092594    0.5011067    0.5143634
# 1    0.6124592   0.6223943    0.6230286   0.62179035
# 2   0.31265894   0.3298276   0.32196087   0.32013485
# 3   0.48540512  0.47907406   0.49889335   0.48563656
# 4      13054.0     12935.0      13299.0      13034.0
# 5   0.27500117  0.29266182   0.28297287   0.28572077
# 6    0.3529295  0.37345603     0.365536   0.36678973
# 7   0.49248818  0.51587087   0.51612645   0.51208663
# 8    3.8126466   3.8578863    3.6716404     3.641493
# 9    0.4797979   0.4894926   0.48391876    0.4844651
# 10   0.5234585   0.5234984    0.5521553   0.53161484
# 11  0.11645367  0.13710658   0.12984835    0.1330347
# 12   0.5726687   0.5841148   0.57969874   0.58211887
# 13  0.42733136   0.4158852    0.4203013   0.41788116
# 14  0.15220748  0.15649596   0.15420675   0.15445054
# 15  0.31265894   0.3298276   0.32196087   0.32013485
# 16   0.2397145   0.2557723   0.24593952   0.24902698
# 17  0.04124446  0.04461102  0.043263912  0.042310927
# 18  0.66879576    0.691728   0.71155274    0.6958525
# 19  0.39013776   0.3955957   0.39269167   0.39300194
# See the whole table with table.as_data_frame()
#
# df_raw12
#
# Cross-Validation Metrics Summary:
#                                    mean            sd   cv_1_valid  \
# 0                  accuracy  0.54466593   0.030313266    0.5025636
# 1                       auc   0.6343176  0.0070356927   0.63346535
# 2                     aucpr  0.37504265   0.010439755    0.3785877
# 3                       err  0.45533404   0.030313266   0.49743637
# 4                 err_count      4872.8      313.4752       5336.0
# 5                  f0point5  0.33268633    0.00870086   0.32171017
# 6                        f1   0.4114783  0.0055142087   0.40763766
# 7                        f2   0.5398508   0.016427407    0.5561951
# 8            lift_top_group   3.4940062    0.21892786    3.6963341
# 9                   logloss   0.5189237  0.0025382421   0.51807153
# 10      max_per_class_error  0.49726382   0.052152567   0.56793875
# 11                      mcc   0.1580637   0.010992215   0.14431088
# 12  mean_per_class_accuracy   0.5928105  0.0069964714   0.58337754
# 13     mean_per_class_error   0.4071895  0.0069964714   0.41662243
# 14                      mse  0.16940323  0.0011009199   0.16901882
# 15                   pr_auc  0.37504265   0.010439755    0.3785877
# 16                precision  0.29508474   0.010113908   0.28207096
# 17                       r2  0.05226152   0.004283395  0.054130774
# 18                   recall   0.6828848     0.0438865    0.7346939
# 19                     rmse   0.4115845  0.0013382138   0.41111898
#
#     cv_2_valid   cv_3_valid   cv_4_valid  cv_5_valid
# 0    0.5578078    0.5759394   0.52415025  0.56286865
# 1    0.6224008    0.6377931    0.6390045   0.6389242
# 2    0.3595672    0.3706101   0.37932688  0.38712135
# 3    0.4421922   0.42406055   0.47584972  0.43713135
# 4       4712.0       4593.0       5054.0      4669.0
# 5   0.33100685   0.34040672    0.3278143   0.3424936
# 6   0.40490022   0.41318512    0.4124622  0.41920638
# 7   0.52126694     0.525546   0.55604315   0.5402026
# 8    3.4050872    3.1557593    3.6463475    3.566502
# 9    0.5220884   0.51896954   0.51527005    0.520219
# 10  0.46866584   0.44405678   0.53579736  0.46986032
# 11   0.1490221   0.16721761   0.16066505  0.16910288
# 12  0.58807254    0.5989323   0.59414214  0.59952796
# 13  0.41192746    0.4010677   0.40585786  0.40047204
# 14  0.17069227   0.16949165   0.16778024  0.17003314
# 15   0.3595672    0.3706101   0.37932688  0.38712135
# 16   0.2951031    0.3046345   0.28836152  0.30525362
# 17  0.04571285  0.050375912  0.054567963   0.0565201
# 18   0.6448109    0.6419214   0.72408164   0.6689162
# 19   0.4131492   0.41169363   0.40960985  0.41235074
# See the whole table with table.as_data_frame()

# %%
# print feat imp for 12 month journey
print(performance_df.loc[3,'varimp'])
# Out:
#                                   variable  relative_importance  \
# 0                        ClientAccountDesc           311.499634
# 1                                   AppAge           276.248657
# 2              PlansAcceptedPast1YearCount           274.688507
# 3                            PlanLiveCount           257.863342
# 4                    ManufacturerBrandCode           241.274979
# 5                   ONS_%people_working_FT           232.545837
# 6                         ONS_avg_bedrooms           190.392044
# 7              PlansAcceptedPast5YearCount           172.148300
# 8                   ONS_population_density           142.732910
# 9                            ApplianceCode           129.561783
# 10                         ClientGroupDesc           121.483597
# 11                           ONS_avg_rooms           116.259758
# 12                             ONS_avg_age           104.791580
# 13                        HPI_AveragePrice           100.683380
# 14   ONS_avg_dependent_children_per_family            98.691772
# 15                         HPI_SalesVolume            90.910500
# 16           ONS_n_families_per_population            89.617805
# 17                 ONS_%people_working_49+            89.610458
# 18                          ONS_n_families            77.123344
# 19                                  relFee            76.809563
# 20                  ONS_avg_household_size            72.053612
# 21             ONS_n_families/n_households            71.942596
# 22                  ONS_bedrooms per rooms            68.555206
# 23                          ONS_population            65.982887
# 24  ONS_avg_distance_travelled_to_work(km)            62.869537
# 25                             GoodsColour            62.411602
# 26                                     Fee            61.702377
# 27                           PurchasePrice            60.954227
# 28                         ClientGroupCode            59.185108
# 29                     ONS_occupation_rate            57.274448
# 30                 PlansActivePast1yrCount            54.520958
# 31                              ClientCode            53.957306
# 32                        ONS_n_households            53.491638
# 33                 ONS_%people_working_sum            46.092789
# 34            PlansCancelledPast5YearCount            45.245869
# 35        ManufacturerGuaranteePartsMonths            29.857500
# 36                              price_diff            25.424454
# 37                               relFeeInc            24.466496
# 38                         offertotalprice            23.605822
# 39                     ClaimPast3YearCount            22.890879
# 40                   ClaimAmount3YearTotal            22.064926
# 41                   ClaimAmount5YearTotal            20.968979
# 42                         HasPrevRTPPrice            15.506096
# 43                 PlansActivePast5yrCount            13.513597
# 44            PlansCancelledPast1YearCount            12.711570
# 45                              price_band            11.691523
# 46                   ClaimAmount1YearTotal             9.807229
# 47                     ClaimPast5YearCount             6.948456
# 48                              TotalPrice             5.628326
# 49                     ClaimPast1YearCount             3.762097
# 50       ManufacturerGuaranteeLabourMonths             2.964410
# 51               PricingVersionDescription             0.000000
#
#     scaled_importance  percentage
# 0            1.000000    0.071725
# 1            0.886835    0.063608
# 2            0.881826    0.063249
# 3            0.827813    0.059375
# 4            0.774559    0.055555
# 5            0.746536    0.053545
# 6            0.611211    0.043839
# 7            0.552644    0.039638
# 8            0.458212    0.032865
# 9            0.415929    0.029832
# 10           0.389996    0.027972
# 11           0.373226    0.026770
# 12           0.336410    0.024129
# 13           0.323222    0.023183
# 14           0.316828    0.022724
# 15           0.291848    0.020933
# 16           0.287698    0.020635
# 17           0.287674    0.020633
# 18           0.247587    0.017758
# 19           0.246580    0.017686
# 20           0.231312    0.016591
# 21           0.230956    0.016565
# 22           0.220081    0.015785
# 23           0.211823    0.015193
# 24           0.201829    0.014476
# 25           0.200359    0.014371
# 26           0.198082    0.014207
# 27           0.195680    0.014035
# 28           0.190001    0.013628
# 29           0.183867    0.013188
# 30           0.175027    0.012554
# 31           0.173218    0.012424
# 32           0.171723    0.012317
# 33           0.147971    0.010613
# 34           0.145252    0.010418
# 35           0.095851    0.006875
# 36           0.081620    0.005854
# 37           0.078544    0.005634
# 38           0.075781    0.005435
# 39           0.073486    0.005271
# 40           0.070835    0.005081
# 41           0.067316    0.004828
# 42           0.049779    0.003570
# 43           0.043382    0.003112
# 44           0.040808    0.002927
# 45           0.037533    0.002692
# 46           0.031484    0.002258
# 47           0.022306    0.001600
# 48           0.018068    0.001296
# 49           0.012077    0.000866
# 50           0.009517    0.000683
# 51           0.000000    0.000000

# %%
# save performance metric to pickle
pd.to_pickle(performance_df, "feat_imp_performance_df.pkl")
